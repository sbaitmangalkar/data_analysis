# %%
import pandas as pd

df = pd.read_csv("/Users/shyambaitmangalkar/my_repos/datasets/titanic/train.csv")
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.Survived
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64
